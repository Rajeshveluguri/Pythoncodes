# %%
# !pip install opendatasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for opendatasets from https://files.pythonhosted.org/packages/00/e7/12300c2f886b846375c78a4f32c0ae1cd20bdcf305b5ac45b8d7eceda3ec/opendatasets-0.1.22-py3-none-any.whl.metadata
# ...

# %%
import opendatasets as od

# %% [markdown]
# Copy the Dataset link from the browser

# %%
dataset = "https://www.kaggle.com/datasets/hellbuoy/car-price-prediction"

# %% [markdown]
# Go to Kaggle website, settings and click on "Create New API Token", Download the JSON file and Enter username and Key to download the dataset.

# %%
od.download(dataset)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: rajeshveluguri
# Your Kaggle Key: ········
# Dataset URL: https://www.kaggle.com/datasets/hellbuoy/car-price-prediction
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 18.1k/18.1k [00:00<00:00, 1.10MB/s]

# %%
import os

# %%
data_dir = '.\car-price-prediction'

# %%
os.listdir(data_dir)
# Out:
# ['CarPrice_Assignment.csv', 'Data Dictionary - carprices.xlsx']

# %%
import pandas as pd

# %%
Car_df = pd.read_csv('CarPrice_Assignment.csv')

# %% [markdown]
# If unable to read CSV file,  please move the CSV file location within Jupyter notebook to Home instead of Folder.

# %%
Car_df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...
