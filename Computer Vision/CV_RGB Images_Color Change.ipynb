# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open('./Pepsi 2 images.jfif')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=389x129>

# %%
img2 = Image.open('C:\Rajesh Veluguri\Personal\Pepsi images.jfif')

# %%
img2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=368x137>

# %%
type(img)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
img.mode
# Out:
# 'RGB'

# %%
img_array = np.array(img)
img_array.shape
# Out:
# (129, 389, 3)

# %%
plt.imshow(img_array)

# %%
img5 = img_array.copy()

# %%
img6 = img_array.copy()

# %%
img7 = img_array.copy()

# %%
img8 = img_array.copy()

# %%
img9 = img_array.copy()

# %%
img5
# Out:
# array([[[  0,  66, 156],
#         [  0,  66, 156],
#         [  0,  66, 156],
#         ...,
#         [  0, 156, 199],
#         [  0, 157, 200],
#         [  0, 159, 202]],
#
#        [[  0,  66, 156],
#         [  0,  66, 156],
#         [  0,  66, 156],
#         ...,
#         [  0, 148, 191],
#         [  0, 149, 192],
#         [  0, 151, 194]],
#
#        [[  0,  66, 156],
#         [  0,  66, 156],
#         [  0,  66, 156],
#         ...,
#         [  0, 137, 181],
#         [  0, 139, 183],
#         [  0, 140, 184]],
#
#        ...,
#
#        [[  0,  69, 174],
#         [  0,  69, 174],
#         [  0,  69, 174],
#         ...,
#         [  0, 134, 200],
#         [  0, 157, 209],
#         [  0, 189, 235]],
#
#        [[  0,  69, 174],
#         [  0,  69, 174],
#         [  0,  69, 174],
#         ...,
#         [  0, 124, 192],
#         [  0, 166, 219],
#         [  0, 178, 226]],
#
#        [[  0,  69, 174],
#         [  0,  69, 174],
#         [  0,  69, 174],
# ...

# %%
img5[:,:,0]
# Out:
# array([[  1,   1,   1, ..., 117, 118, 120],
#        [  1,   1,   1, ..., 109, 110, 112],
#        [  1,   1,   1, ...,  96,  98,  99],
#        ...,
#        [  2,   2,   2, ...,  56,  67, 135],
#        [  2,   2,   2, ...,  59,  86, 130],
#        [  2,   2,   2, ...,  43,  49, 126]], dtype=uint8)

# %% [markdown]
# Eliminating RED Color, 0 for RED, 1 for Green and 2 for Blue

# %%
img5[:,:,0] = 0
plt.imshow(img5)

# %%
img8[:,:,1]
# Out:
# array([[ 66,  66,  66, ..., 156, 157, 159],
#        [ 66,  66,  66, ..., 148, 149, 151],
#        [ 66,  66,  66, ..., 137, 139, 140],
#        ...,
#        [ 69,  69,  69, ..., 134, 157, 189],
#        [ 69,  69,  69, ..., 124, 166, 178],
#        [ 69,  69,  69, ..., 126, 125, 189]], dtype=uint8)

# %% [markdown]
# Eliminating Green Color

# %%
img8[:,:,1] = 0
plt.imshow(img8)

# %%
img9[:,:,2]
# Out:
# array([[156, 156, 156, ..., 199, 200, 202],
#        [156, 156, 156, ..., 191, 192, 194],
#        [156, 156, 156, ..., 181, 183, 184],
#        ...,
#        [174, 174, 174, ..., 200, 209, 235],
#        [174, 174, 174, ..., 192, 219, 226],
#        [174, 174, 174, ..., 194, 183, 233]], dtype=uint8)

# %% [markdown]
# Eliminating Blue color

# %%
img9[:,:,2] = 0
plt.imshow(img9)

# %% [markdown]
# Testing with Bird JPG

# %%
imgbird = Image.open('C:\Rajesh Veluguri\Personal\color_compare.jpg')
imgbird
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x167>

# %%
imgbird_array = np.array(imgbird)
imgbird_array.shape
# Out:
# (167, 500, 3)

# %%
imgb1 = imgbird_array.copy()

# %%
imgb2 = imgbird_array.copy()
imgb3 = imgbird_array.copy()

# %%
imgb1[:,:,0] = 0
plt.imshow(imgb1)

# %%
imgb2[:,:,1] = 0
plt.imshow(imgb2)

# %%
imgb3[:,:,2] = 0
plt.imshow(imgb3)

# %% [markdown]
# Now Testing on Holi image

# %%
imgholi = Image.open('./Picture1.jpg')
imgholi
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=629x850>

# %%
imgholi_array = np.array(imgholi)
imgholi_array.shape
# Out:
# (850, 629, 3)

# %%
imgholi1 = imgholi_array.copy()
imgholi2 = imgholi_array.copy()
imgholi3 = imgholi_array.copy()

# %%
imgholi1[:,:,0] = 0
plt.imshow(imgholi1)

# %%
imgholi2[:,:,1] = 0
plt.imshow(imgholi2)

# %%
imgholi3[:,:,2]=0
plt.imshow(imgholi3)
