# %% [markdown]
# #### Binary Threshold
# x,y = maxvalue if src(x,y) > Threshold else '0'
#
# #### Inverted Binary
# x,y = '0' if src(x,y) > Threshold else 'Max value'
#
# #### Truncated
# x,y = Threshold if src(x,y) > Threshold else src(x,y)
#
# #### To Zero
# x,y = src(x,y) if src(x,y) > Threshold else '0'
#
# #### To Zero Inverted
# x,y = '0' if src(x,y) > Thresold else 'src(x,y)'

# %% [markdown]
# ##### cv.THRESH_BINARY
# lim,img1 = cv.threshold(img,127,255,cv.THRESH_BINARY)
# ##### cv.THRESH_BINARY_INV
# lim,img2 = cv.threshold(img,127,255,cv.THRESH_BINARY_INV)
# ##### cv.THRESH_TRUNC
# lim,img3 = cv.threshold(img,127,255,cv.THRESH_TRUNC)
# ##### cv.THRESH_TOZERO
# lim,img4 = cv.threshold(img,127,255,cv.THRESH_TOZERO)
# ##### cv.THRESH_TOZERO_INV
# lim,img5 = cv.threshold(img,127,255,cv.THRESH_TOZERO_INV)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('./hummingbird.jpg')
plt.imshow(img)

# %% [markdown]
# ### The first argument is the source image, which should be a grayscale image
# ### The second argument is the threshold value which is used to classify the pixel values
# ### The third argument is the maximum value which is assigned to pixel values exceeding the threshold
# ### OpenCV provides different types of thresholding which is given by the fourth parameter of the function.

# %%
lim,img = cv2.threshold(img, 100,255,cv2.THRESH_BINARY)
plt.imshow(img, cmap = 'gray')

# %%
lim,img = cv2.threshold(img, 200,255,cv2.THRESH_BINARY)
plt.imshow(img, cmap = 'gray')

# %%
lim,img = cv2.threshold(img, 250,255,cv2.THRESH_BINARY)
plt.imshow(img, cmap = 'gray')

# %% [markdown]
# Now we will try Inverted Binary

# %%
lim,img = cv2.threshold(img, 250,255,cv2.THRESH_BINARY_INV)
plt.imshow(img, cmap = 'gray')

# %%
img = cv2.imread('./hummingbird.jpg')
ret,thresh1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
ret,thresh2 = cv2.threshold(img,127,255,cv2.THRESH_BINARY_INV)
ret,thresh3 = cv2.threshold(img,127,255,cv2.THRESH_TRUNC)
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray',vmin=0,vmax=255)
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
 
plt.show()

# %%
img = cv2.imread('./hummingbird.jpg')
ret,thresh11 = cv2.threshold(img,200,255,cv2.THRESH_BINARY)
ret,thresh12 = cv2.threshold(img,200,255,cv2.THRESH_BINARY_INV)
ret,thresh13 = cv2.threshold(img,200,255,cv2.THRESH_TRUNC)
ret,thresh14 = cv2.threshold(img,200,255,cv2.THRESH_TOZERO)
ret,thresh15 = cv2.threshold(img,200,255,cv2.THRESH_TOZERO_INV)

titles = ['Original Image','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh11, thresh12, thresh13, thresh14, thresh15]

for i in range(6):
    plt.subplot(2,3,i+1),plt.imshow(images[i],'gray',vmin=0,vmax=255)
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
 
plt.show()
