# %% [markdown]
# <center><img src="https://github.com/insaid2018/Term-1/blob/master/Images/INSAID_Full%20Logo.png?raw=true" width="240" height="100" /></center>
#
# # <center><b>Data Manipulation with Pandas<b></center>

# %% [markdown]
# ---
# # **Table of Contents**
# ---
#
# **1.** [**Introduction to Pandas**](#Section1)<br>
# **2.** [**Installing & Importing Libraries**](#Section2)<br>
#   - **2.1** [**Installing Libraries**](#Section21)
#   - **2.2** [**Importing Libraries**](#Section22)
#
# **3.** [**Pandas Series & Indexing**](#Section3)<br>
# **4.** [**Pandas DataFrames**](#Section4)<br>
#   - **4.1** [**DataFrame Creation**](#Section41)
#   - **4.2** [**Loading Files into DataFrame**](#Section42)
#   - **4.3** [**DataFrame Attributes**](#Section43)
#   - **4.4** [**Access, Add & Drop Operations**](#Section44)
#   - **4.5** [**DataFrame Indexing**](#Section45)
#   - **4.6** [**Append, Concat & Merge Operations**](#Section46)
#   - **4.7** [**Data Filteration**](#Section47)
#   - **4.8** [**Multi-Indexed DataFrames**](#Section48)
#   - **4.9** [**Groupby in Pandas**](#Section49)
#   - **4.10** [**DataFrame Operations**](#Section410)
#   - **4.11** [**Time Series Operations**](#Section411)
#
# **5.** [**Conclusion**](#Section5)<br>

# %% [markdown]
# ---
# <a name = Section1></a>
# # **1. Introduction to Pandas**
# ---
#
# - Pandas is a **software library** written for the Python programming language for **data manipulation and analysis**.
#
# - The library is **highly optimized** for performance, with critical code paths **written in Cython or C**.
#
# - In particular, it **offers data structures** and **operations** for manipulating numerical tables and time series.
#
# - The name Pandas is derived from the word
# “panel data”, a term for multidimensional data. The term "**panel data**" is an econometrics term for data sets.
#
# ### **Cross Sectional Vs Time series Vs Panel data ??**
# - Cross sectional data is collection of data about **multiple subjects**
# at **particular point of time**. It's a snapshot view.
# - Time series data is the data about one subject collected **over multiple time intervals**.
# - Panel data is the combination of both. It is observation of multiple subjects over multiple time intervals.
#
#
#
#
#
# <center><img src="https://upload.wikimedia.org/wikipedia/commons/e/ed/Pandas_logo.svg"></center>
#
# **Library Features:**
#
# - DataFrame object for data manipulation with **integrated indexing**.
#
# - Tools for reading and writing data between **in-memory data structures** and **different file formats**.
#
# - **Data alignment** and integrated handling of missing data.
#
# - **Reshaping, merging, joining, filtration** and **pivoting** of data sets.
#
# - **Label-based slicing, fancy indexing**, and subsetting of large data sets.
#
# - Data structure column **insertion** and **deletion**.
#
# - **Group by** engine allowing split-apply-combine operations on data sets.
#
# - **Hierarchical axis indexing** to work with high-dimensional data in a lower-dimensional data structure.
#
# - **Time series-functionalities** such as:
#
#   - Date range generation and frequency conversion,
#
#   - Moving window statistics, moving window linear regressions, date shifting and lagging.

# %% [markdown]
# #References
# * Coffee with Pandas ebook https://drive.google.com/file/d/1Wnh4xk0YfCxteABuKGf5iNwBH_-3v1kE/view
# * Cheatsheets https://blog.finxter.com/pandas-cheat-sheets/
# * https://www.machinelearningplus.com/python/101-pandas-exercises-python/
# * https://github.com/guipsamora/pandas_exercises
# * https://pynative.com/python-pandas-exercise/
# * https://github.com/justmarkham/pandas-videos

# %% [markdown]
# ---
# <a name = Section2></a>
# # **2. Installing & Importing Libraries**
# ---
#
# - To refer to the official documentation of Pandas click <a href="https://pandas.pydata.org/docs/">**here**</a>.

# %% [markdown]
# <a name = Section21></a>
# ### **2.1 Installing Libraries**

# %%
# !pip install -q --user pandas

# %% [markdown]
# <a name = Section22></a>
# ### **2.2 Importing Libraries**
#
# - We can give an alias name of pd, so that we dont have to repeatedly use the longer form of the name.

# %%
import pandas as pd                                                 # For Panel data analysis
import numpy as np                                                  # Importing package numpys (For Numerical Python)
import seaborn as sns                                               # Visualization package, but we'll be using for data only

# %%
# Know the version of your package
pd.__version__
# Out:
# '1.5.3'

# %%
np.__version__
# Out:
# '1.23.5'

# %% [markdown]
# ---
# <a name = Section3></a>
# # **3. Pandas Series & Indexing**
# ---
#
# - Pandas series is a **one-dimensional ndarray** capable of storing any type of data with **axis labels** (including time series).
#
# - The axis labels are called index and they need not be unique

# %%
# Creating a list called countries
countries = ['India','France','England']

# Creating a list called capitals
capitals = ['New Delhi','Paris','London']

# Creating 1-D array using capitals list
arr = np.array(capitals)
arr
# Out:
# array(['New Delhi', 'Paris', 'London'], dtype='<U9')

# %%
# Creating pandas series using python list
pd.Series(data=capitals)
# Out:
# 0    New Delhi
# 1        Paris
# 2       London
# dtype: object

# %%
# Creating pandas series using numpy array
pd.Series(data=arr)
# Out:
# 0    New Delhi
# 1        Paris
# 2       London
# dtype: object

# %%
# Creating a dictionary with index as alphabets and values as numerics
dicts = {'a':10, 'b':20, 'c':30, 'd':40, 'e':50, 'f':60, 'g':70, 'h':80}

# Creating pandas series using dictionary
my_series =  pd.Series(data=dicts)

# %%
print(my_series)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# h    80
# dtype: int64

# %%
my_series['a'] # returns the value for the index 'a'.... my_series[0] also returns the same o/p
# Out:
# 10

# %%
my_series[0]
# Out:
# 10

# %%
my_series['h'] #my_series[-1] as well will return the same value
# Out:
# 80

# %%
# Dict with duplicate keys... restricction on a dict (can't have duplicate keys)
dicts = {'a':10, 'b':20, 'c':30, 'd':40, 'e':50, 'f':60, 'g':70, 'h':80, 'h':800}

# Creating pandas series using dictionary
my_series1 =  pd.Series(data=dicts)

print(dicts)
print(my_series1)
print(my_series1.index) # printing the attribute of the pandas series
# Out:
# {'a': 10, 'b': 20, 'c': 30, 'd': 40, 'e': 50, 'f': 60, 'g': 70, 'h': 800}
# a     10
# b     20
# c     30
# d     40
# e     50
# f     60
# g     70
# h    800
# dtype: int64
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'], dtype='object')

# %%
# Creating a dictionary with index as alphabets and values as numerics
num_dicts = {1:10, 2:20, 3:30}

# Creating pandas series using dictionary
num_series = pd.Series(data=num_dicts)
print(num_series)
print(num_series.index)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
# Int64Index([1, 2, 3], dtype='int64')

# %%
# Creating a custom pandas series using capitals as its data and countries as its index
print(capitals)
print(countries)
capitals_series = pd.Series(data=capitals, index=countries)
print("\n Custom series using capitals as its data and countries as its index \n", capitals_series)
# Out:
# ['New Delhi', 'Paris', 'London']
# ['India', 'France', 'England']
#
#  Custom series using capitals as its data and countries as its index
#  India      New Delhi
# France         Paris
# England       London
# dtype: object

# %%
capitals_series.index
# Out:
# Index(['India', 'France', 'England'], dtype='object')

# %%
capitals_series["England"]
# Out:
# 'London'

# %%
# Creating a list called countries
countries1 = ['India','France','England','India','India']

# Creating a list called capitals
capitals1 = ['New Delhi','Paris','London','ND','Delhi']

# Create custom series
dup_series = pd.Series(data=capitals1, index = countries1)

#print
print(dup_series)
# Out:
# India      New Delhi
# France         Paris
# England       London
# India             ND
# India          Delhi
# dtype: object

# %%
dup_series.index
# Out:
# Index(['India', 'France', 'England', 'India', 'India'], dtype='object')

# %%
# accessing an INDEX which is duplicated
dup_series['India']
# Out:
# India    New Delhi
# India           ND
# India        Delhi
# dtype: object

# %%
dup_series[1] # access a series using default index. Both custom and default index work
# Out:
# 'Paris'

# %%
print(type(my_series))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# **Observation:**
#
# - Pandas series can be created using various inputs.
#
# - Through the above examples, we learned how to create pandas series using a list, array, and dictionary.

# %% [markdown]
# **Series Indexing:** Now we will observe how indexing works in case of pandas series.

# %%
# Creating a dictionary with index as alphabets and values as numerics
dicts = {'a':10, 'b':20, 'c':30, 'd':40, 'e':50, 'f':60, 'g':70, 'h':80}

# Creating pandas series using dictionary
my_series = pd.Series(data=dicts)

# Output the series
my_series
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# h    80
# dtype: int64

# %%
# Accessing first element present in the series
my_series[0]
# Out:
# 10

# %%
# Accessing first element present in the series using its index
my_series['a']
# Out:
# 10

# %%
print(capitals_series)
# Out:
# India      New Delhi
# France         Paris
# England       London
# dtype: object

# %%
# Let's print the capital of India
capitals_series['India']

# %% [markdown]
# **Note:** Even though you pass explicit indexes to the series while creating a series, the implicit indexing is still valid.

# %%
print(my_series)

# %%
# Accessing first three elements present in the series
my_series[:3]
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
# Accessing elements ranging from 3 to 7
my_series[3:7]
# Out:
# d    40
# e    50
# f    60
# g    70
# dtype: int64

# %%
# Accessing elements using label indexes a, b, and c as a list
my_series[['a', 'd', 'f']]
# Out:
# a    10
# d    40
# f    60
# dtype: int64

# %% [markdown]
# Behaviour of custom and range indexing...

# %%
# Accessing elements ranging from label a index to label c index
print(my_series)
my_series['a':'f']
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# h    80
# dtype: int64
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# dtype: int64

# %%
my_series[0:5]
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
my_series
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# h    80
# dtype: int64

# %%
# What is the ouput of the following ?
my_series + my_series
# Out:
# a     20
# b     40
# c     60
# d     80
# e    100
# f    120
# g    140
# h    160
# dtype: int64

# %%
my_series * 3
# Out:
# a     30
# b     60
# c     90
# d    120
# e    150
# f    180
# g    210
# h    240
# dtype: int64

# %% [markdown]
# Above command outputs the result of element-wise mathematical operations - same as Numpy does

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_series
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# h    80
# dtype: int64

# %%
my_series.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'], dtype='object')

# %%
my_series.shape
# Out:
# (8,)

# %%
my_series.dtype
# Out:
# dtype('int64')

# %%
my_series.size
# Out:
# 8

# %%
my_series.empty
# Out:
# False

# %%
my_series.hasnans
# Out:
# False

# %%
my_series.nbytes
# Out:
# 64

# %%
# empty pd series
empty_series = pd.Series()
print(empty_series)
print(empty_series.empty)
# Out:
# Series([], dtype: float64)
# True
# <ipython-input-46-b698954c9512>:2: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   empty_series = pd.Series()

# %%
my_series
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# h    80
# dtype: int64

# %%
my_series[0] = 100

# %%
my_series
# Out:
# a    100
# b     20
# c     30
# d     40
# e     50
# f     60
# g     70
# h     80
# dtype: int64

# %% [markdown]
# **Observation:**
#
# - As we have accessed one and multiple elements in Numpy arrays, we can do it here also in a similar fashion using index or labels.
#
# - In the last example, we saw that element-wise mathematical operations can be performed on series.

# %% [markdown]
# ---
# <a name = Section4></a>
# # **4. Pandas DataFrames**
# ---
#
# - The dataFrames are **2D data structures** having data aligned in **tabular format**.
#
# - The data is aligned in **rows** (also called **index**) and columns and can store any datatypes like int, string, float, boolean.
#
# - They are **highly flexible** and offer a lot of **mathematical functions**.
#
# - In this section, we will learn several aspects of the pandas dataframe and its working.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <a name = Section41></a>
# ## **4.1 DataFrame Creation**
#
# - First of all we will explore how pandas dataframes are created. So, let's get started...

# %% [markdown]
# **Creating a DataFrame from a List**

# %%
# Creating a list called fruits
fruits = ['Apple', 'Banana', 'Coconut', 'Dates']

# Creating a pandas dataframe using fruits list
fruits_df = pd.DataFrame(data=fruits, columns=['Fruit'])

# Output the pandas dataframe
fruits_df
# Out:
#      Fruit
# 0    Apple
# 1   Banana
# 2  Coconut
# 3    Dates

# %%
fruits_df.ndim
# Out:
# 2

# %%
pd.Series(data=fruits).ndim
# Out:
# 1

# %%
type(fruits_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Create a Pandas dataframe using a series
pd.DataFrame(data=my_series,columns=['Marks'])
# Out:
#    Marks
# a     10
# b     20
# c     30
# d     40
# e     50
# f     60
# g     70
# h     80
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_0, *['Marks'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_1, *['Marks'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_2, *['Marks', 'count()', None], **{})
# chart
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(_df_3, *['Marks'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_4, *['Marks'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   figsize = (10 * figscale, 5.2 * figscale)
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(_df_5, *['Marks', 'count()', None], **{})
# chart

# %% [markdown]
# **Creating a DataFrame from Nested Lists**

# %%
# Initiate a list of lists
people = [['Rick', 60, 'O+'], ['Morty', 10, 'O+'], ['Summer', 45, 'A-'], ['Beth', 18, 'B+']]

# Creating a pandas dataframe using people list
people_df = pd.DataFrame(data=people, columns=['Name', 'Age', 'Blood Group'])

# Output the pandas dataframe

people_df
# Out:
#      Name  Age Blood Group
# 0    Rick   60          O+
# 1   Morty   10          O+
# 2  Summer   45          A-
# 3    Beth   18          B+

# %% [markdown]
# **Creating a DataFrame from a Dictionary**

# %%
# Initiate a dictionary
people = {'Name': ['Rick', 'Morty', 'Summer', 'Beth'],
                   'Blood Group': ['O+', 'O+', 'A-', 'B+'],
           'Age': [60, 10, 45, 18]}

# Creating a pandas dataframe using people list
people_df = pd.DataFrame(data=people)

# Output the pandas dataframe
people_df
# Out:
#      Name Blood Group  Age
# 0    Rick          O+   60
# 1   Morty          O+   10
# 2  Summer          A-   45
# 3    Beth          B+   18

# %%
# poll question
D1 = pd.DataFrame([{'a':10, 'b':20}, {'a':5, 'b':10, 'c':20}])
print(D1)
D1.shape
# Out:
#     a   b     c
# 0  10  20   NaN
# 1   5  10  20.0
# (2, 3)

# %% [markdown]
# **Observation:**
#
# - From the above examples you get to know how to create dataframes using various inputs like lists, nested lists, and a dicitionary.
#
# - Also note that pandas dataframes are mutable and potentially hetrogenous tabular data structure.

# %% [markdown]
# <a name = Section42></a>
# ## **4.2 Loading Files into DataFrame**
#
# - DataFrames can load data from many types of files like **csv, json, excel sheets, text**, etc.
#
# - You can **also load files** in dataframe present on the web by **providing url** in the parameter list.
#
# - Below all the methods explained are applicable for the web files too.
#
# - Lets learn how to do this one by one, first by using:

# %% [markdown]
# **Loading CSV file into DataFrame**

# %%
# Loading csv files using pandas .read_csv() method
csv_df = pd.read_csv(filepath_or_buffer='https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Casestudy/supermarkets.csv')

# Output the dataframe
csv_df

# %%
# Let's read an google colab inbuilt sample data
pd.read_csv(filepath_or_buffer="/content/sample_data/california_housing_test.csv")

# %% [markdown]
# **Loading JSON file into DataFrame**

# %%
# Loading json files using pandas .read_json() method
json_df = pd.read_json(path_or_buf='https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Casestudy/supermarkets.json')

# Output the dataframe
json_df

# %% [markdown]
# **Loading Excel file into DataFrame**

# %%
# Loading first sheet from excel file using pandas .read_excel() method
excel_df = pd.read_excel(io='https://github.com/insaid2018/Term-1/blob/master/Data/Casestudy/supermarkets.xlsx?raw=true', sheet_name='Ark1')

# Output the dataframe
excel_df

# %% [markdown]
# **Loading CSV files separated by semi-colon ;**

# %%
# Loading csv files using pandas .read_csv() method
txt_df = pd.read_csv('https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Casestudy/supermarkets-semi-colons.txt', sep=';')

# Output the dataframe
txt_df

# %% [markdown]
# **Observation:**
#
# - We observed how to load data from various types of files such as csv, json, excel etc.
#
# - We also used sep argument to segment the datasheet by various formats.
#
# - There are many more parameters that one must explore to find hidden functionalities.

# %% [markdown]
# <a name = Section43></a>
# ## **4.3 DataFrame Attributes**
#
# - After loading your DataFrame you may be interested to know about the **columns, shape, datatypes**.
#
# - There are many functions in pandas to check all the different attributes of a DataFrame.

# %%
# Loading csv files using pandas .read_csv() method
data = pd.read_csv(filepath_or_buffer='https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Casestudy/supermarkets.csv')

# Output the dataframe
data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Check the number of dimensions of a dataframw... isn't it obvious ??? :)
data.ndim

# %%
# Get column names of a dataframe
data.columns

# %%
# To get the data types of each column in the dataframe
data.dtypes

# %%
data

# %%
# To transpose a data frame
data.T

# %%
# Get column and row indexes
data.axes

# %% [markdown]
# **DataFrame Shape**

# %%
# To check the resolution of the dataframe
print('Shape of the DataFrame:', data.shape)

# %% [markdown]
# **DataType of Columns**

# %%
# To check the data types of columns in dataframe
print('Data Type of Columns\n', data.dtypes)

# %% [markdown]
# **Information about the Dataset**

# %%
data.info()

# %% [markdown]
# **Get Total Records in Columns**

# %%
data.head()

# %% [markdown]
# **Get Index range of Dataset**

# %%
data.index

# %% [markdown]
# **Set Column as Index**

# %% [markdown]
# Index is like an address, that's how any data point across the dataframe or series can be accessed. Rows and columns both have indexes, rows indices are called as index and for columns its general column names.

# %%
data

# %%
# Creating a new dataframe and setting Name as index
data2 = data.set_index(keys='Name')

# Output the dataframe
data2

# %%
data2.index

# %% [markdown]
# **Observation:**
#
# - We observed various dataframe attributes and its associated functions that we can use to extract basic information about the data.

# %% [markdown]
# <a name = Section44></a>
# ## **4.4 Access, Add & Drop Operations**
#
# - In this section, we will see how to perform basic DataFrame operations like,
#
#   - Access Columns in a Dataframe
#
#   - Adding Column to Existing Column in a Dataframe
#
#   - Drop Rows or Columns in a Dataframe

# %%
# Loading csv files using pandas .read_csv() method
data = pd.read_csv(filepath_or_buffer='https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Casestudy/supermarkets.csv')

# Output the dataframe
data
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# **Selecting Rows or Columns in a Dataframe**

# %%
# Selecting Address column from the dataset
# Accessing one column from dataframe will return a series
print(data['Address'])
# Out:
# 0       3666 21st St
# 1     735 Dolores St
# 2        332 Hill St
# 3       3995 23rd St
# 4    1056 Sanchez St
# 5    551 Alvarado St
# Name: Address, dtype: object

# %%
print(type(data['Address']))
print(data['Address'].shape)
# Out:
# <class 'pandas.core.series.Series'>
# (6,)

# %%
# Using a list to select columns
data[['Address']]
# Out:
#            Address
# 0     3666 21st St
# 1   735 Dolores St
# 2      332 Hill St
# 3     3995 23rd St
# 4  1056 Sanchez St
# 5  551 Alvarado St

# %%
print(type(data[['Address']]))
print("Shape : ",data[['Address']].shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Shape :  (6, 1)

# %%
# Selecting multiple columns from the dataset using a list of column names
data[['Name', 'Address']]
# Out:
#           Name          Address
# 0      Madeira     3666 21st St
# 1  Bready Shop   735 Dolores St
# 2  Super River      332 Hill St
# 3   Ben's Shop     3995 23rd St
# 4      Sanchez  1056 Sanchez St
# 5   Richvalley  551 Alvarado St

# %%
type(data[['Address', 'Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# **Adding Column to Existing Dataframe**

# %%
# Creating a new column of Salary in a dataframe
data['Salary'] = [10000, 20000, 30000, 40000, 50000, 60000]

# Output the dataframe
data
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees  Salary
# 0          8   10000
# 1         15   20000
# 2         25   30000
# 3         10   40000
# 4         12   50000
# 5         20   60000

# %%
# Creating a new column using existing columns
data['Total Salary'] = data['Employees'] * data['Salary']

# Output the dataframe
data
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees  Salary  Total Salary
# 0          8   10000         80000
# 1         15   20000        300000
# 2         25   30000        750000
# 3         10   40000        400000
# 4         12   50000        600000
# 5         20   60000       1200000

# %%
data['EPF'] = data['Salary'] * 0.12
data
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees  Salary  Total Salary      PF     EPF
# 0          8   10000         80000  1200.0  1200.0
# 1         15   20000        300000  2400.0  2400.0
# 2         25   30000        750000  3600.0  3600.0
# 3         10   40000        400000  4800.0  4800.0
# 4         12   50000        600000  6000.0  6000.0
# 5         20   60000       1200000  7200.0  7200.0

# %% [markdown]
# - These processes are generally used in Feature Engineering where we combine 2 or more columns to create more meaningful features.

# %% [markdown]
# **Deleting Rows or Columns in a Dataframe**

# %%
# Loading csv files using pandas .read_csv() method
# data = pd.read_csv(filepath_or_buffer='https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Casestudy/supermarkets.csv')

# Calling data object that we modified earlier
data
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees  Salary  Total Salary      PF     EPF
# 0          8   10000         80000  1200.0  1200.0
# 1         15   20000        300000  2400.0  2400.0
# 2         25   30000        750000  3600.0  3600.0
# 3         10   40000        400000  4800.0  4800.0
# 4         12   50000        600000  6000.0  6000.0
# 5         20   60000       1200000  7200.0  7200.0

# %% [markdown]
# **What is the importance of inplace ?**

# %%
# Drop ID column along column axis in original dataframe
data.drop(labels=['ID'], axis=1)
# Out:
#            Address           City             State Country         Name  \
# 0     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2      332 Hill St  San Francisco  California 94114     USA  Super River
# 3     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees  Salary  Total Salary      PF     EPF
# 0          8   10000         80000  1200.0  1200.0
# 1         15   20000        300000  2400.0  2400.0
# 2         25   30000        750000  3600.0  3600.0
# 3         10   40000        400000  4800.0  4800.0
# 4         12   50000        600000  6000.0  6000.0
# 5         20   60000       1200000  7200.0  7200.0

# %%
# lets check the data now to see if ID column has vanished
data
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees  Salary  Total Salary      PF     EPF
# 0          8   10000         80000  1200.0  1200.0
# 1         15   20000        300000  2400.0  2400.0
# 2         25   30000        750000  3600.0  3600.0
# 3         10   40000        400000  4800.0  4800.0
# 4         12   50000        600000  6000.0  6000.0
# 5         20   60000       1200000  7200.0  7200.0

# %% [markdown]
# !!!!!!!!!!!! BAM !!!!!!!!! ID column still exists... But why ??!!??

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Inplace is an argument used in different functions. Some functions in which inplace is used as an attributes like, set_index(), dropna(), fillna(), reset_index(), drop(), replace() and many more. The default value of this attribute is False and it returns the copy of the object.

# %%
# Drop ID column along column axis in original dataframe
# Setting the inplace=False will not perform any operations on original data. It is False by default.
data.drop(labels=['ID'], axis=1, inplace=True)

# Output the modified dataframe
data
# Out:
#            Address           City             State Country         Name  \
# 0     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2      332 Hill St  San Francisco  California 94114     USA  Super River
# 3     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees  Salary  Total Salary      PF     EPF
# 0          8   10000         80000  1200.0  1200.0
# 1         15   20000        300000  2400.0  2400.0
# 2         25   30000        750000  3600.0  3600.0
# 3         10   40000        400000  4800.0  4800.0
# 4         12   50000        600000  6000.0  6000.0
# 5         20   60000       1200000  7200.0  7200.0

# %% [markdown]
# - To drop rows we need pass the index of the rows in .drop() function.

# %%
# Dropping first record with affecting our original dataset
data.drop(labels=[0], axis=0, inplace=True) # inplace is False by default hence we need not be explicit

# %%
data
# Out:
#            Address           City             State Country         Name  \
# 1   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2      332 Hill St  San Francisco  California 94114     USA  Super River
# 3     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees  Salary  Total Salary      PF     EPF
# 1         15   20000        300000  2400.0  2400.0
# 2         25   30000        750000  3600.0  3600.0
# 3         10   40000        400000  4800.0  4800.0
# 4         12   50000        600000  6000.0  6000.0
# 5         20   60000       1200000  7200.0  7200.0

# %% [markdown]
# - You can also use labels as index for the rows and drop rows based on those labels.

# %%
data.index
# Out:
# RangeIndex(start=1, stop=6, step=1)

# %%
# Creating a new variable where Name column is set as index
data2 = data.set_index(keys=['Name'])

# Output the dataframe
data2
# Out:
#                      Address           City             State Country  \
# Name
# Bready Shop   735 Dolores St  San Francisco          CA 94119     USA
# Super River      332 Hill St  San Francisco  California 94114     USA
# Ben's Shop      3995 23rd St  San Francisco          CA 94114     USA
# Sanchez      1056 Sanchez St  San Francisco        California     USA
# Richvalley   551 Alvarado St  San Francisco          CA 94114     USA
#
#              Employees  Salary  Total Salary      PF     EPF
# Name
# Bready Shop         15   20000        300000  2400.0  2400.0
# Super River         25   30000        750000  3600.0  3600.0
# Ben's Shop          10   40000        400000  4800.0  4800.0
# Sanchez             12   50000        600000  6000.0  6000.0
# Richvalley          20   60000       1200000  7200.0  7200.0

# %%
data2.index
# Out:
# Index(['Bready Shop', 'Super River', 'Ben's Shop', 'Sanchez', 'Richvalley'], dtype='object', name='Name')

# %%
# Let's check what's there in data
data
# Out:
#            Address           City             State Country         Name  \
# 1   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2      332 Hill St  San Francisco  California 94114     USA  Super River
# 3     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees  Salary  Total Salary      PF     EPF
# 1         15   20000        300000  2400.0  2400.0
# 2         25   30000        750000  3600.0  3600.0
# 3         10   40000        400000  4800.0  4800.0
# 4         12   50000        600000  6000.0  6000.0
# 5         20   60000       1200000  7200.0  7200.0

# %%
# lets check the index of data
data.index
# Out:
# RangeIndex(start=1, stop=6, step=1)

# %%
# lets check the index of data2
data2.index

# %% [markdown]
# Notice that the 'data' has the default index and the 'data2' has the column 'Name' as its index.
# Reason : inplace = False by default does not impact the original data frame on which the operation is performed.

# %% [markdown]
# **Observation:**
#
# - We have seen how to use select, add, and drop records or columns from a dataframe.
#
# - The use of these operations may differ according to the objective need.
#
# - For example, you use **dropping operations** when you have **null data** or **outliers**.
#
# - Understood the use of **inplace** parameter.

# %% [markdown]
# <a name = Section45></a>
# ## **4.5 DataFrame Indexing**
#
# - There are **two types** of indexing that we can perform in Pandas dataframe.
#
#   - Using numbers (row or column index) using .iloc[].
#
#   - Using names (row name or column name) using .loc[].

# %%
market_df = pd.read_csv(filepath_or_buffer='https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Casestudy/supermarkets.csv')
market_df
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %% [markdown]
# **Indexing using .iloc[]**: Purely integer-location based indexing for selection by position.

# %%
# Accessing top 4 rows and 2nd and 3rd columns in a dataframe
market_df.iloc[0:4,1:3] # Indexing similar to numpy arrays.
# Out:
#           Address           City
# 0    3666 21st St  San Francisco
# 1  735 Dolores St  San Francisco
# 2     332 Hill St  San Francisco
# 3    3995 23rd St  San Francisco

# %%
# Accessing rows (all) and first 5 columns in a dataframe
market_df.iloc[:, 0:5]
# Out:
#    ID          Address           City             State Country
# 0   1     3666 21st St  San Francisco          CA 94114     USA
# 1   2   735 Dolores St  San Francisco          CA 94119     USA
# 2   3      332 Hill St  San Francisco  California 94114     USA
# 3   4     3995 23rd St  San Francisco          CA 94114     USA
# 4   5  1056 Sanchez St  San Francisco        California     USA
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA

# %%
# Accessing rows till 4th index and columns (all) in a dataframe
market_df.iloc[0:4, :]
# Out:
#    ID         Address           City             State Country         Name  \
# 0   1    3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2  735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3     332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4    3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10

# %%
market_df.loc[0:4,:]
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12

# %% [markdown]
# **Indexing using .loc[]**: Access a group of rows and columns by label(s) or a boolean array.

# %%
# Accessing all rows and columns (Address) in a dataframe
# As we are accessing only one column it will be returned as a series
market_df.loc[:, 'Address']
# Out:
# 0       3666 21st St
# 1     735 Dolores St
# 2        332 Hill St
# 3       3995 23rd St
# 4    1056 Sanchez St
# 5    551 Alvarado St
# Name: Address, dtype: object

# %%
market_df['Address']
# Out:
# 0       3666 21st St
# 1     735 Dolores St
# 2        332 Hill St
# 3       3995 23rd St
# 4    1056 Sanchez St
# 5    551 Alvarado St
# Name: Address, dtype: object

# %%
type(market_df.loc[:, 'Address'])
# Out:
# pandas.core.series.Series

# %%
# Accessing rows (1st to 4th index) and columns (Address to Country) in a dataframe
display(market_df)
market_df.loc[1:4, 'Address':'Country']
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20
#            Address           City             State Country
# 1   735 Dolores St  San Francisco          CA 94119     USA
# 2      332 Hill St  San Francisco  California 94114     USA
# 3     3995 23rd St  San Francisco          CA 94114     USA
# 4  1056 Sanchez St  San Francisco        California     USA

# %% [markdown]
# Do you notice anything interesting about indexing using loc ??
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The ways slicing indexes work is different in loc and iloc

# %%
# Accessing rows (all) and columns (State to all) in a dataframe
market_df.loc[:, 'State':]
# Out:
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
market_df
# Out:
#           Name  Employees           City          Address  ID Country  \
# 0      Madeira          8  San Francisco     3666 21st St   1     USA
# 1  Bready Shop         15  San Francisco   735 Dolores St   2     USA
# 2  Super River         25  San Francisco      332 Hill St   3     USA
# 3   Ben's Shop         10  San Francisco     3995 23rd St   4     USA
# 4      Sanchez         12  San Francisco  1056 Sanchez St   5     USA
# 5   Richvalley         20  San Francisco  551 Alvarado St   6     USA
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
market_df = market_df[['Name','Employees','City','Address','ID','Country','State']]

# %% [markdown]
# **Observation:**
#
# - We observed how to index data elements (rows and columns) using .loc[] and .iloc[].
#
# - You can use these operations to separate features into numerical and categorical columns.

# %% [markdown]
# <a name = Section46></a>
# ## **4.6 Append, Concat & Merge Operations**
#
# - In this section we will see how to append, merge and concatenate two or more dataframes.

# %% [markdown]
# **Appending DataFrames**: For full documentation of the function click <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html">**here**</a>.

# %%
# Creating custom data of data science students
data_dict = {'id':[1, 2, 3, 4, 5], 'name':['Suchit', 'Mohit', 'Mukesh', 'Hemanka', 'Ashish'],
             'language':['English', 'Hindi', 'Punjabi', 'Hindi', 'Hindi']}

# Creating dataframe out of data_dict variable
df1 = pd.DataFrame(data=data_dict)

# Output the dataframe
df1
# Out:
#    id     name language
# 0   1   Suchit  English
# 1   2    Mohit    Hindi
# 2   3   Mukesh  Punjabi
# 3   4  Hemanka    Hindi
# 4   5   Ashish    Hindi

# %%
# Creating another dataframe that contains only one row
df2 = pd.DataFrame(data={'id': [6], 'name': ['Hiren'], 'language': ['English']})

# Output the dataframe
df2
# Out:
#    id   name language
# 0   6  Hiren  English

# %%
# Creating a third dataframe by appending df2 to df1
df3 = df1.append(other=df2)

# Output the dataframe
df3
# Out:
# <ipython-input-48-6227968b8ebb>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df1.append(other=df2)
#    id     name language
# 0   1   Suchit  English
# 1   2    Mohit    Hindi
# 2   3   Mukesh  Punjabi
# 3   4  Hemanka    Hindi
# 4   5   Ashish    Hindi
# 0   6    Hiren  English

# %% [markdown]
# **Observation:**
#
# - Did you observed the index of the row from second dataframe?
#
# - Well there a solution to that as well, just set ignore_index to True.

# %%
# Creating a third dataframe by appending df2 to df1 and ingoring index
df3 = df1.append(other=df2, ignore_index=True)

# Output the dataframe
df3
# Out:
# <ipython-input-49-b45f1ed6b158>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df3 = df1.append(other=df2, ignore_index=True)
#    id     name language
# 0   1   Suchit  English
# 1   2    Mohit    Hindi
# 2   3   Mukesh  Punjabi
# 3   4  Hemanka    Hindi
# 4   5   Ashish    Hindi
# 5   6    Hiren  English

# %% [markdown]
# **Concatenating DataFrames**: For full documentation of the function click <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html">**here**</a>.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Append is the specific case of concat, which concats the second dataframe’s records at the end of first dataframe.
#
# Append has no axis argument.
#
# Syntax of Append is different from Concat.

# %%
# Creating custom dataset 1
data_dict1 = {'id': [1, 2, 3, 4, 5], 'name': ['a', 'b', 'c', 'd', 'e'],
              'sub': ['sub1', 'sub2', 'sub3', 'sub4', 'sub5']
              }

# Creating custom dataset 2
data_dict2 = {'id': [1, 2, 3, 4, 5], 'name': ['b', 'c', 'd', 'e', 'f'],
              'sub': ['sub3', 'sub4', 'sub5', 'sub6', 'sub7']
              }

# Creating dataframes out of custom data dictionaries
df1 = pd.DataFrame(data=data_dict1)
df2 = pd.DataFrame(data=data_dict2)

# %%
df1
# Out:
#    id name   sub
# 0   1    a  sub1
# 1   2    b  sub2
# 2   3    c  sub3
# 3   4    d  sub4
# 4   5    e  sub5

# %%
df2
# Out:
#    id name   sub
# 0   1    b  sub3
# 1   2    c  sub4
# 2   3    d  sub5
# 3   4    e  sub6
# 4   5    f  sub7

# %%
# Creating a third dataframe by concatenating df2 to df1 along row axis
df3 = pd.concat(objs=[df1, df2], axis=0)

# Output the dataframe
df3
# Out:
#    id name   sub
# 0   1    a  sub1
# 1   2    b  sub2
# 2   3    c  sub3
# 3   4    d  sub4
# 4   5    e  sub5
# 0   1    b  sub3
# 1   2    c  sub4
# 2   3    d  sub5
# 3   4    e  sub6
# 4   5    f  sub7

# %%
# Oh the indexes... Let's set them right with ignore_index param
df3 = pd.concat(objs=[df1, df2], axis=0,  ignore_index=True)

# Output the dataframe
df3
# Out:
#    id name   sub
# 0   1    a  sub1
# 1   2    b  sub2
# 2   3    c  sub3
# 3   4    d  sub4
# 4   5    e  sub5
# 5   1    b  sub3
# 6   2    c  sub4
# 7   3    d  sub5
# 8   4    e  sub6
# 9   5    f  sub7

# %%
# Creating a third dataframe by concatenating df2 to df1 along column axis
df3 = pd.concat(objs=[df1, df2], axis=1)

# Output the dataframe
df3
# Out:
#    id name   sub  id name   sub
# 0   1    a  sub1   1    b  sub3
# 1   2    b  sub2   2    c  sub4
# 2   3    c  sub3   3    d  sub5
# 3   4    d  sub4   4    e  sub6
# 4   5    e  sub5   5    f  sub7

# %%
pd.concat(objs=[df1, df2], axis=1,ignore_index=True)
# Out:
#    0  1     2  3  4     5
# 0  1  a  sub1  1  b  sub3
# 1  2  b  sub2  2  c  sub4
# 2  3  c  sub3  3  d  sub5
# 3  4  d  sub4  4  e  sub6
# 4  5  e  sub5  5  f  sub7

# %% [markdown]
# **Merging DataFrames**: For full documentation of the function click <a href="https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html">**here**</a>.
#
# - Merging can happen on a columns that have common name or we can specify how to join two tables.
#
# - There are following types of merging that we can perform on two dataframes:
#
#   - **Left Join:** It use only **keys from left frame**, similar to a SQL left outer join; preserve key order.
#
#   - **Right Join:** It use only **keys from right frame**, similar to a SQL right outer join; preserve key order.
#
#   - **Outer Join:** It use union of **keys from both frames**, similar to a SQL full outer join; sort keys lexicographically.
#
#   - **Inner Join (default):** It use **intersection** of **keys from both frames**, similar to a SQL inner join; preserve the order of the left keys.
#
#   - **Cross Join:** It creates the **cartesian product** from **both frames**, preserves the order of the left keys.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Creating custom dataset 1
data_dict1 = {'emp_id': [1, 2, 3, 4, 5], 'emp_name': ['a', 'b', 'c', 'd', 'e'],
              'sub': ['sub1', 'sub2', 'sub3', 'sub4', 'sub5']
              }

# Creating custom dataset 2
data_dict2 = {'dept_id': [1, 2, 3, 4, 5], 'dept_name': ['b', 'c', 'd', 'e', 'f'],
              'sub': ['sub3', 'sub4', 'sub5', 'sub6', 'sub7']
              }

# Creating dataframes out of custom data dictionaries
df1 = pd.DataFrame(data=data_dict1)
df2 = pd.DataFrame(data=data_dict2)

# %%
display(df1)
display(df2)
# Out:
#    emp_id emp_name   sub
# 0       1        a  sub1
# 1       2        b  sub2
# 2       3        c  sub3
# 3       4        d  sub4
# 4       5        e  sub5
#    dept_id dept_name   sub
# 0        1         b  sub3
# 1        2         c  sub4
# 2        3         d  sub5
# 3        4         e  sub6
# 4        5         f  sub7

# %%
# Merging dataframe df1 and df2 based on common column name
pd.merge(left=df1, right=df2, on='sub')
# Out:
#    emp_id emp_name   sub  dept_id dept_name
# 0       3        c  sub3        1         b
# 1       4        d  sub4        2         c
# 2       5        e  sub5        3         d

# %%
# Merging dataframe df1 and df2 based on df1's sub values
pd.merge(left=df1, right=df2, on='sub', how='left')
# Out:
#    emp_id emp_name   sub  dept_id dept_name
# 0       1        a  sub1      NaN       NaN
# 1       2        b  sub2      NaN       NaN
# 2       3        c  sub3      1.0         b
# 3       4        d  sub4      2.0         c
# 4       5        e  sub5      3.0         d

# %%
# Merging dataframe df1 and df2 based on df2's sub values
pd.merge(left=df1, right=df2, left_on='sub',right_on='sub', how='right')
# Out:
#    emp_id emp_name   sub  dept_id dept_name
# 0     3.0        c  sub3        1         b
# 1     4.0        d  sub4        2         c
# 2     5.0        e  sub5        3         d
# 3     NaN      NaN  sub6        4         e
# 4     NaN      NaN  sub7        5         f

# %%
# Merging dataframe df1 and df2 based on union of both sub column
pd.merge(left=df1[['emp_id','name']], right=df2, how='outer',left_on="sub",right_on = "sub")
# Out:
#    emp_id emp_name   sub  dept_id dept_name
# 0     1.0        a  sub1      NaN       NaN
# 1     2.0        b  sub2      NaN       NaN
# 2     3.0        c  sub3      1.0         b
# 3     4.0        d  sub4      2.0         c
# 4     5.0        e  sub5      3.0         d
# 5     NaN      NaN  sub6      4.0         e
# 6     NaN      NaN  sub7      5.0         f

# %%
# Merging dataframe df1 and df2 based on union of both sub column
pd.merge(left=df1, right=df2)
# Out:
#    emp_id emp_name   sub  dept_id dept_name
# 0       3        c  sub3        1         b
# 1       4        d  sub4        2         c
# 2       5        e  sub5        3         d

# %% [markdown]
# #### Join Vs Merge
# Both join and merge can be used to combines two dataframes but the join method combines two dataframes on the basis of their indexes whereas the merge method is more versatile and allows us to specify columns beside the index to join on for both dataframes.

# %% [markdown]
# **Observation:**
#
# - We learned how to concatenate, merge and append dataframes using corresponding functions.
#
# - They are widely used while collecting data from multiple data sources.

# %% [markdown]
# <a name = Section47></a>
# ## **4.7 Data Filteration**
#
# - In this section, we will observe how to perform data filtration operations.
#
# - Remember? the **output** of the **comparison** is of **boolean data** type i.e. True or False.
#
# - You can use this **boolean** to **filter** out **records** from the DataFrame.

# %%
# Loading remote csv files using pandas .read_csv() method and setting ID as index
#market_df = pd.read_csv(filepath_or_buffer='http://pythonhow.com/supermarkets.csv')

# Output the dataframe
market_df

# %%
# Returns True of False if Employees are greater than 15
market_df['Employees'] >= 15

# %% [markdown]
# - We can use the above output in a dataframe to filter out important information.

# %%
# Filter out all the rows where Employees are greater than equal to 15
market_df[market_df['Employees'] >= 15]

# %%
(market_df['Employees'] >= 15) & (market_df['State'] != 'CA 94119')

# %%
# Filter out all the rows where Employees >= 15 and State is not equal to CA 94119
market_df[(market_df['Employees'] >= 15) & (market_df['State'] != 'CA 94119')]

# %% [markdown]
# **Observation:**
#
# - We observed how easy it is to filter out information from the dataframes.
#
# - They also help us to get a clear picture of data by logically operating on combinations of various features.
#
# - Therefore these functions are widely used in Feature Engineering.

# %% [markdown]
# <a name = Section49></a>
# ## **4.8 Groupby in Pandas**
#
# - Groupby allows you to **group together rows** based on a **column** and perform an **aggregate function** on them.
#
# - This is quiet a handy tool if you don't want to change the index of the DataFrame.
#
# - Follows **Split Apply Combine Process**
# - The groupby() function splits the data based on some criteria.
# - The aggregate function is applied to each of the groups and then combined together to create the result DataFrame. The below diagram illustrates this behavior with a simple example.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Loading synthetic data present in seaborn library
tips = sns.load_dataset(name='tips', cache=True)

# Output top 5 rows of the dataframe
tips.head()

# %%
tips.info()

# %%
tips.head()

# %%
# Find the number of lunch and dinner bills using groupby
tips.groupby(by="time").size()

# %%
tips['time'].value_counts()

# %%
tips.head(5)

# %%
# Group by data based on time column estimating total rows
tips.groupby(by=['time']).count()

# %%
# Group by data based on time column estimating mean of numerical columns
tips.groupby(by=['time']).mean()

# %%
# Group by data based on time column estimating mean of numerical columns
tips.groupby(by=['time']).agg({'total_bill':'mean'})

# %% [markdown]
# TIP - The group by output will have an index or multiple indexes (headers) corresponding to your chosen grouping variables. To avoid setting this index, pass “as_index=False” or “.reset_index()” to the groupby operation.

# %%
tips.groupby(by=['time']).agg({'total_bill':'mean'}).reset_index()

# %%
# Group by data based on time column estimating min and max of total_bill and sum of tip
tips.groupby('time').agg({'total_bill': ['min', 'max'],
                          'tip': ['min','sum','max','count']})

# %% [markdown]
# **Observation:**
#
# - We observed how useful groupby method is when it comes to analyzing data.

# %% [markdown]
# <a name = Section410></a>
# ## **4.9 DataFrame Operations**
#
# - There are some basic operations that we can apply on any dataframe and these are as follows:
#   - **.unique():** Hash table-based unique values are returned in order of appearance.
#
#   - **.nunique():** Count distinct observations over requested axis.
#
#   - **.value_counts():** Return a Series containing counts of unique values.
#
#   - **.apply():** Apply a function along an axis of the DataFrame.
#
#   - **.sort_values():** Sort by the values along either axis.

# %%
# Creating a list of lists
people = [['Rick', 60, 'O+'], ['Morty', 10, 'O+'], ['Summer', 45, 'A-'], ['Beth', 18, 'B+']]
# Creating dataframe out of people list
people_df = pd.DataFrame(data=people, columns=['Name', 'Score', 'Blood Group'])

# Output the dataframe
people_df

# %%
# Display the unique labels in Blood Group
print('Unique values in Blood Group:', people_df['Blood Group'].unique())

# Dispaly the unique count in Blood Group
print('Unique count in Blood Group:', people_df['Blood Group'].nunique())

# %%
# Return a Series of Blood Group containing counts of unique values.
people_df['Blood Group'].value_counts()

# %%
people_df

# %%
# Define a function that can return the double of a number
def times2(x):
    return x*2

# %%
# Apply a times2 function along an axis of the DataFrame.
# people_df['Score Times2'] = people_df['Score'].apply(lambda x: x * 2)
people_df['Score Times2'] = people_df['Score'].apply(times2)

# Output the dataframe
people_df

# %%
# Smarter way using lambda
#people_df['new_score'] = people_df['Score'].apply(lambda x : x * 2)

# %%
# Sort the dataframe based on score column in ascending order
people_df.sort_values(by='Name', ascending=False,inplace=True)

# %%
people_df

# %% [markdown]
# **Observation:**
#
# - We observed various operations that can be applied on the dataframe.

# %% [markdown]
# <a name = Section411></a>
# ## **4.10 Time Series Operations**
#
# - In this section, we will observe how to perform time series related operations when time as a factor is associcated.

# %%
# Loading remote csv files using pandas .read_csv() method and setting ID as index
air_df = pd.read_csv(filepath_or_buffer='https://raw.githubusercontent.com/insaid2018/Term-1/master/Data/Casestudy/AirQualityUCI.csv')

# Output the top 5 rows in dataframe
air_df.head()

# %% [markdown]
# - Let's get some basic information about the columns in our dataset.

# %%
air_df.info()

# %% [markdown]
# - We can observe that **Date** and **Time** features are **identified as object**, **instead** they **should be datetime**.
#
# - We can **correct** this **schema** by **casting** it to the datetime along with specific datetime format.
#
# - For better visibility we will take only first row for now.

# %%
air_df['Date_Time'] = air_df['Date'] + " "+ air_df['Time']
air_df.head()

# %%
air_df['Date_Time'] = pd.to_datetime(arg=air_df['Date_Time'], format='%m/%d/%Y %H:%M:%S')

# Display the type of the Date column
print('Date Type:', air_df['Date_Time'].dtype)

# %%
air_df.head(1)

# %%
# Casting Date column to datetime format
air_df['Date'] = pd.to_datetime(arg=air_df['Date'], format='%m/%d/%Y')

# %%
air_df.head(5)

# %%
air_df.info()

# %% [markdown]
# - Now let's do the same for Time column.

# %%
# Casting Time column to datetime format
air_df['Time'] = pd.to_datetime(arg=air_df['Time'], format='%H:%M:%S')

# Display the type of the Time column
print('Time Type:', air_df['Time'].dtype)

# %% [markdown]
# - Now, we will see how to extract day, month and year from any date.
#
# - For ease of understanding, we will be using only one row.

# %%
air_df['Date_Time'].tail(1)

# %%
air_df['Date_Time'].dt.year

# %%
# Extract day from Date column
# We used index to extract only value not a series
#day = air_df['Date'].head(1).dt.day[0]
day = air_df['Date_Time'].dt.day[0]

# Extract month from Date column
# We used index to extract only value not a series
month = air_df['Date_Time'].dt.month[0]

# Extract year from Date column
# We used index to extract only value not a series
year = air_df['Date_Time'].dt.year[0]

# Display day
print('Day:', day)

# Display month
print('Month:', month)

# Display year
print('Year:', year)

# %%
type(air_df['Date_Time'].dt)

# %% [markdown]
# The code air_df['Date'].dt.day extracts the day component from the "Date" column of a Pandas DataFrame called air_df.
#
# The dt attribute is used to access the datetime properties of a Pandas Series, and the day attribute extracts the day of the month as an integer value (ranging from 1 to 31) from each datetime value in the "Date" column.
#
# This code can be useful when working with time series data and you want to extract specific components of a datetime value for further analysis, such as filtering by day or aggregating by day.

# %%
# Display the number of unique days
print('Number of Unique Days:', air_df['Date'].dt.day.nunique())

# Display the number of unique months
print('Number of Unique Months:', air_df['Date'].dt.month.nunique())

# Display the number of unique years
print('Number of Unique Year:', air_df['Date'].dt.year.nunique())

# %% [markdown]
# - Next, we will see how to extract week number, day of the week, weekday name, day of the year.
#
# - For the sake of simplicity we will be only using first row.
#
# - The __index of week days__ are provided below.
#
#   - 0 = Monday
#   - 1 = Tuesday
#   - 2 = Wednesday
#   - 3 = Thursday
#   - 4 = Friday
#   - 5 = Saturday
#   - 6 = Sunday

# %%
sample_date = air_df['Date'].head(1)
print(sample_date)

# %%
help(sample_date.dt)

# %%
sample_date.dt.month_name()

# %%
# Display the week number
print('Week Number:', sample_date.dt.isocalendar().week[0])

# Display the day of the week
print('Day of the week:', sample_date.dt.day_of_week[0])

# Display weekday name
print('Weekday name:', sample_date.dt.day_name()[0])

# Display day of the year
print('Day of the year:', sample_date.dt.dayofyear[0])

# %% [markdown]
# * sample_date: This is a Pandas datetime object representing the date "2004-03-10".
# * dt: This converts the value to a datetime format (even though it's already in datetime format in this case).
# * isocalendar(): This returns a tuple containing the ISO year, ISO week number, and ISO weekday for the datetime value.
# * week: This selects the ISO week number from the tuple.

# %% [markdown]
# - Next, we will see how to get hours, minutes, seconds from Time column.
#
# - For the sake of simplicity we will take only first row as an example.

# %%
sample_time = air_df['Date_Time'].head(1)
print(sample_time)

# %%
sample_time.dt.min

# %%
# Display hours from Time column
print('Hours:', sample_time.dt.hour[0])

# Display minutes from Time column
print('Minutes:', sample_time.dt.minute[0])

# Display seconds from Time column
print('Seconds:', sample_time.dt.second[0])

# %% [markdown]
# - We can also perform **conditional filtering** over the rows of dataframe **using datetime** type data.
#
# - Below, we will show you an exmpale how to measure the number of records before 9 a.m.

# %%
print(air_df.shape)
print(f"First Date : {air_df['Date_Time'][0]}, Last Date: {air_df['Date_Time'][9356]}")

# %%
# Initiating a custom timestap of 01/01/2005 9 AM
timestamp = pd.to_datetime(arg="01/01/2005 09:00:00", format='%d/%m/%Y %H:%M:%S')

# Display the number of records that are below than the defined timestamp
print('Filtered Data Shape:', air_df[air_df['Date_Time'] > timestamp].shape)

# %% [markdown]
# - Let's try to filter the rows that are before 01/01/2005 date.

# %%
# Initiating a custom date of 01/01/2005
datestamp = pd.to_datetime("01/01/2005", format='%d/%m/%Y')

print(datestamp)
# Ouput 5 rows that are before 01/01/2005
air_df[air_df['Date_Time'] < datestamp].tail()

# %% [markdown]
# **Observation:**
#
# - We have seen that by using datetime format we can extract information like year, month, hour, minute, etc from time.
#
# - We can even retrieve the name of the day and day of the year type information.
#
# - All these things **help** to better **understand** our **data** which in turn help in **drawing** important **conclusions** and **insights**.

# %% [markdown]
# ---
# <a name = Section5></a>
# # **5. Conclusion**
# ---
#
# - **Python** is a **great language** for doing data analysis, primarily because of the fantastic ecosystem of data-centric Python packages.
#
# - Pandas is one of those packages and makes **importing** and **analyzing** **data** much **easier**.
#
# - It is an **open-source**, **BSD-licensed** Python library providing high-performance, easy-to-use data structures, and data analysis tools.
#
# - Python with **Pandas** is **used in a wide range of fields** including academic and commercial domains like finance, statistics, etc.
#
# - They are **built on packages like NumPy and matplotlib** to give you a convenient place to do data analysis and visualization work.

# %% [markdown]
# **<center><h2>That's All Folks!</h2></center>**

# %% [markdown]
# # Bonus Section
# Another example of inplace

# %% [markdown]
# Let's use replace() function to understand inplace

# %%
# creating dataframe
dataframe=pd.DataFrame({'Name':['Shobhit','Vaibhav',
								'Vimal','Sourabh'],

						'Class':[11,12,10,9],
						'Age':[18,20,21,17]})

# Checking created dataframe
# copied dataframe
print("\nOriginal Dataframe... \n",dataframe)

# %%
# without using inplace renaming the column
new_data = dataframe.rename(columns = {'Name':'FirstName'})

# Copied dataframe
print("New data frame... \n",new_data)

# checking whether dataframe is modified or not
# Original dataframe
print("\nOriginal Dataframe... \n",dataframe)

# %%
# putting inplace=False
new_data_2 = dataframe.rename(columns = {'Name':'FirstName'},
							inplace = False)

# Copied dataframe
print("New data frame 2... \n",new_data_2)

# checking whether dataframe is modified or not
# Original dataframe
print("\nOriginal Dataframe... \n",dataframe)

# %%
# Putting Inplace=True
dataframe.rename(columns = {'Name':'FirstName'},
				inplace = True)

# checking whether dataframe is modified or not
# Original dataframe
print("\nOriginal Dataframe... \n",dataframe)

# %% [markdown]
# <a name = Section48></a>
# ## **Multi-Indexed DataFrames**
#
# - Until now you have seen DataFrames with a single index.
#
# - Lets see how we can use more than 1 index to gain better insights.

# %%
# Creating custom data dictionary of company
company_df = {'Company':['Google', 'Google', 'Google', 'Microsoft', 'Microsoft', 'Microsoft'],
              'Year' : [2008, 2009, 2010, 2008, 2009, 2010],
              'Revenue' : [11, 15, 16, 9, 12, 14],
              'Employee' : [300, 400, 500, 350, 450, 550]
              }

# Creating custom dataframe out of company_df
cmp_df = pd.DataFrame(data=company_df)

# Output the dataframe
cmp_df

# %% [markdown]
# - Now we will set Company and Year as index and try to access rows.

# %%
# Set Company and Year as index values
cmp_df.set_index(keys=['Company', 'Year'], inplace=True)

# Display the output the modified dataframe
cmp_df

# %% [markdown]
# - Let's say we are interested in accessing data for **Google** of year **2009**.
#
# - We won't be able to access data directly and we will end up getting error as shown below:

# %%
cmp_df.loc[2009]

# %%
# Accessing data by using .loc[] two times
cmp_df.loc['Google'].loc[2009]

# %% [markdown]
# - The above approach is not bad, but there's a **better way** we can peform **accessing of rows** that are **indexed** with **multiple** values.
#
# - We will use **.xs()** function of pandas.

# %%
cmp_df

# %%
# Accessing Microsoft data at Company level or index level 0
cmp_df.xs(key='Microsoft', level='Company')

# %%
# Accessing data of year 2009
cmp_df.xs(key=2009, level='Year')

# %% [markdown]
# **Observation:**
#
# - When dealing with multiple indices we have seen how to access data using .xs() function.
#
# - Also, we have seen creating an index using categorical variables.

# %% [markdown]
# Another example of multi-indexing over different dataset.

# %%
# Loading synthetic data present in seaborn library
tips = sns.load_dataset(name='tips', cache=True)

# Extracting only top 10 rows
tips = tips.head(10)

# Output the dataframe
tips

# %%
# Setting sex and size as index of the dataframe
tips.set_index(keys=['sex','size'], inplace=True)

# Output the dataframe
tips

# %%
# Sorting out the index in ascending order
tips.sort_index(inplace=True)

# Output the dataframe
tips

# %%
tips.xs(key=4,level='size')

# %%
# Access all records where size = 2
tips.xs(key=2, level='size')

# %%
x = np.arange(10,1,-1)
print(x)
# Acess by index - as a list
x[[3,3,1,8]]
